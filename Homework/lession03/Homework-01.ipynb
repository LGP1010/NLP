# %%
from collections import defaultdict
start_price= [1, 5, 8, 9, 10, 17, 17, 20, 24, 30, 35]
price_dic = defaultdict(int)
for i, p in enumerate(start_price):
    price_dic[i+1] = p
price_dic
# Out:
# defaultdict(int,
#             {1: 1,
#              2: 5,
#              3: 8,
#              4: 9,
#              5: 10,
#              6: 17,
#              7: 17,
#              8: 20,
#              9: 24,
#              10: 30,
#              11: 35})

# %%
def fibonacci(n):
    if n  <= 2:
        return 1
    else:
        return fibonacci(n-1) + fibonacci(n-2)
print(fibonacci(30))
# Out:
# 832040

# %%
mem = defaultdict()
def fibo(n):
    if n == 0:
        mem[0] = 0
        return n
    if n == 1 or n == 2:
        mem[n] = 1
        return 1
    if n in mem:
        return mem[n]
    else:
        res = fibo(n-1) + fibo(n-2)
        mem[n] = res
        return res

# %%
print(fibo(30))
# Out:
# 832040

# %%
from functools import wraps

# %%
def memo(f):
    already_computed = {}
    @wraps(f)
    def _wrap(arg):
        if arg in already_computed:
            result = already_computed[arg]
        else:
            result = f(arg)
            already_computed[arg] = result
        return result
    return _wrap

# %%
solution = {}

# %%
@memo
def r(n):
    """
    Args: n is the iron length
    Return: the max revenue 
    """
    max_price, max_split = max(
        [(price_dic[n], 0)] + [(r(i) + r(n-i), i) for i in range(1, n)], key=lambda x: x[0]
    )

    solution[n] = (n - max_split, max_split)
    
    return max_price

# %%
price_dic
# Out:
# defaultdict(int,
#             {1: 1,
#              2: 5,
#              3: 8,
#              4: 9,
#              5: 10,
#              6: 17,
#              7: 17,
#              8: 20,
#              9: 24,
#              10: 30,
#              11: 35})

# %%
r(20)
# Out:
# 60

# %%
solution
# Out:
# {1: (1, 0),
#  2: (2, 0),
#  3: (3, 0),
#  4: (2, 2),
#  5: (3, 2),
#  6: (6, 0),
#  7: (6, 1),
#  8: (6, 2),
#  9: (6, 3),
#  10: (10, 0),
#  11: (11, 0),
#  12: (11, 1),
#  13: (11, 2),
#  14: (11, 3),
#  15: (13, 2),
#  16: (14, 2),
#  17: (11, 6),
#  18: (17, 1),
#  19: (17, 2),
#  20: (17, 3)}

# %%
def parse_solution(n):
    left_split, right_split = solution[n]
    
    if right_split == 0: return [left_split]
    
    return parse_solution(left_split) + parse_solution(right_split)

# %%
# 编辑距离是NLP基本的度量文本相似度的算法，可以作为文本相似任务的重要特征之一，
# 其可应用于诸如拼写检查、论文查重、基因序列分析等多个方面。
# 但是其缺点也很明显，算法基于文本自身的结构去计算，并没有办法获取到语义层面的信息。
# 由于需要利用矩阵，故空间复杂度为O(MN)。这个在两个字符串都比较短小的情况下，能获得不错的性能。
def Edit_Distance(str1, str2):
    """
    计算字符串 str1 和 str2 的编辑距离
    :param str1
    :param str2
    :return:
    """
    matrix = [[ i + j for j in range(len(str2) + 1)] for i in range(len(str1) + 1)]

    for i in range(1, len(str1)+1):
        for j in range(1, len(str2)+1):
            if(str1[i-1] == str2[j-1]):
                d = 0
            else:
                d = 1
            
            matrix[i][j] = min(matrix[i-1][j]+1, matrix[i][j-1]+1, matrix[i-1][j-1]+d)

    return matrix[len(str1)][len(str2)]

# %%
Edit_Distance('ABCDECG','ABCCEF')
# Out:
# 3

# %%
# !pip install -i https://pypi.tuna.tsinghua.edu.cn/simple pinyin
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#   Created wheel for pinyin: filename=pinyin-0.4.0-cp36-none-any.whl size=3630491 sha256=f4b22fb92b38b2716c56b09f1cb185dbe99c5a57412d4392e380f128e55bed9a
#   Stored in directory: C:\Users\LGP\AppData\Local\pip\Cache\wheels\c2\63\22\a78568882eb3124c4cfb72c9eff2d6c35fd29bcf2741317f12
# Successfully built pinyin
# ...
# WARNING: You are using pip version 19.2.3, however version 20.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
read_chinese = open('article_9k.txt',encoding='utf-8').read()

# %%
read_chinese[:60]
# Out:
# '此外自本周6月12日起除小米手机6等15款机型外其余机型已暂停更新发布含开发版体验版内测稳定版暂不受影响以确保工程师可以'

# %%
import pinyin
import re

# %%
pinyin.get('你好，自然语言处理',format='strip',delimiter=' ')
# Out:
# 'ni hao ， zi ran yu yan chu li'

# %%
def chinese_to_pinyin(chinese):
    return pinyin.get(chinese, format='strip', delimiter=' ')

# %%
chinese_character = chinese_to_pinyin(read_chinese)

# %%
print(len(chinese_character))
chinese_character[:50]
# Out:
# 129433034
# 'ci wai zi ben zhou 6 yue 1 2 ri qi chu xiao mi sho'

# %%
def tokens(text):
    return re.findall('[a-z]+', text.lower())
tokens(chinese_character[:100])
# Out:
# ['ci',
#  'wai',
#  'zi',
#  'ben',
#  'zhou',
#  'yue',
#  'ri',
#  'qi',
#  'chu',
#  'xiao',
#  'mi',
#  'shou',
#  'ji',
#  'deng',
#  'kuan',
#  'ji',
#  'xing',
#  'wai',
#  'qi',
#  'yu',
#  'ji',
#  'xing',
#  'yi']

# %%
from collections import Counter, defaultdict

# %%
Tokens = tokens(chinese_character)

# %%
pinyin_count = Counter(tokens(chinese_character))

# %%
pinyin_count.most_common(10)
# Out:
# [('shi', 860634),
#  ('de', 809887),
#  ('n', 691114),
#  ('yi', 682478),
#  ('ji', 645276),
#  ('guo', 430042),
#  ('zhong', 409418),
#  ('zhi', 398612),
#  ('xin', 359619),
#  ('li', 355441)]

# %%
def split_word(word):
    return [(word[:i], word[i:]) for i in range(len(word)+1)]

# %%
split_word('nihao')
# Out:
# [('', 'nihao'),
#  ('n', 'ihao'),
#  ('ni', 'hao'),
#  ('nih', 'ao'),
#  ('niha', 'o'),
#  ('nihao', '')]

# %%
alphabet = 'abcdefghijklmnopqrstuvwxyz'
def edit_1_dis(word):
    split_chara = split_word(word)
    delete = [a+b[1:] for a, b in split_chara if b]
    transpose = [a+b[1]+b[0]+b[2:] for a,b in split_chara if len(b)>1]
    replace = [a+c+b[1:] for a,b in split_chara for c in alphabet if b]
    insert = [a+c+b for (a,b) in split_chara for c in alphabet]
    return set(delete + transpose + replace + insert)

# %%
edit_1_dis('pinyin')
# Out:
# {'ainyin',
#  'apinyin',
#  'binyin',
#  'bpinyin',
#  'cinyin',
#  'cpinyin',
#  'dinyin',
#  'dpinyin',
#  'einyin',
#  'epinyin',
#  'finyin',
#  'fpinyin',
#  'ginyin',
#  'gpinyin',
#  'hinyin',
#  'hpinyin',
#  'iinyin',
#  'inyin',
#  'ipinyin',
#  'ipnyin',
#  'jinyin',
#  'jpinyin',
#  'kinyin',
#  'kpinyin',
#  'linyin',
#  'lpinyin',
#  'minyin',
#  'mpinyin',
#  'ninyin',
#  'npinyin',
#  'oinyin',
#  'opinyin',
#  'painyin',
#  'panyin',
#  'pbinyin',
#  'pbnyin',
#  'pcinyin',
#  'pcnyin',
#  'pdinyin',
#  'pdnyin',
#  'peinyin',
#  'penyin',
#  'pfinyin',
#  'pfnyin',
#  'pginyin',
#  'pgnyin',
#  'phinyin',
#  'phnyin',
#  'pianyin',
#  'piayin',
#  'pibnyin',
#  'pibyin',
#  'picnyin',
#  'picyin',
#  'pidnyin',
#  'pidyin',
#  'pienyin',
#  'pieyin',
#  'pifnyin',
#  'pifyin',
#  'pignyin',
#  'pigyin',
#  'pihnyin',
#  'pihyin',
#  'piinyin',
#  'piiyin',
#  'pijnyin',
#  'pijyin',
#  'piknyin',
#  'pikyin',
#  'pilnyin',
#  'pilyin',
#  'pimnyin',
#  'pimyin',
# ...

# %%
def edit0s(word):
    return{word}
def edit2s(word):
    return {m for a in edit_1_dis(word) for m in edit_1_dis(a)}

# %%
edit2s('pinyin')
# Out:
# {'ppioyin',
#  'psenyin',
#  'pdiknyin',
#  'pisyinq',
#  'pieyoin',
#  'umpinyin',
#  'pihndyin',
#  'pinqyitn',
#  'piyyein',
#  'hpinmyin',
#  'piniyhin',
#  'pbnsin',
#  'puinyn',
#  'jindin',
#  'pleyin',
#  'pnyinn',
#  'pintyain',
#  'pinyqine',
#  'pinoyil',
#  'tbpinyin',
#  'wpwnyin',
#  'plinyim',
#  'piinywin',
#  'wfpinyin',
#  'pidnyiin',
#  'ainyien',
#  'xifnyin',
#  'ypindyin',
#  'pinlis',
#  'cinywin',
#  'pihysin',
#  'pipyir',
#  'pirnyiny',
#  'winyuin',
#  'pipnlyin',
#  'pinyrdin',
#  'pinjdyin',
#  'gienyin',
#  'pijyii',
#  'piinyian',
#  'pinqyid',
#  'pdnyikn',
#  'pindyijn',
#  'pionyn',
#  'opixnyin',
#  'epinsin',
#  'pinygsin',
#  'piodyin',
#  'pcinayin',
#  'piocnyin',
#  'avpinyin',
#  'tpinyun',
#  'hpinylin',
#  'gpinyil',
#  'pinihyin',
#  'pinyipp',
#  'ptnyio',
#  'pinyxqn',
#  'phinoyin',
#  'pinaxin',
#  'pqnymin',
#  'pitytin',
#  'pivyirn',
#  'upinyino',
#  'pibneyin',
#  'piqyimn',
#  'psinyind',
#  'piwlnyin',
#  'pinyviyn',
# ...

# %%
def known(word):
    return {w for w in word if w in pinyin_count}
def correct(word):
    can = (known(edit0s(word)) or
                  known(edit_1_dis(word)) or
                  known(edit2s(word)) or
                  [word])
#     print(can)
    return max(can,key=pinyin_count.get)

# %%
correct('yign')
# Out:
# {'yin', 'ying'}
# 'ying'

# %%
def sequence_corect(sentence):
    return ' '.join(map(correct, sentence.split()))

# %%
sequence_corect('zeh sih iy ge ce sho')
# Out:
# {'zen', 'zhe', 'zei', 'ze'}
# {'si', 'shi'}
# {'i', 'y', 'yi'}
# {'ge'}
# {'ce'}
# {'shuo', 'sha', 'shou', 'shao', 'she', 'sao', 'shi', 'shu', 'suo'}
# 'zhe shi yi ge ce shi'

# %%
# pinyin_count Tokens
Token_str = [str(t) for t in Tokens]
token_2_gram = [''.join(Token_str[i:i+2]) for i in range(len(Token_str[:-1]))]
len(token_2_gram)
# Out:
# 31273776

# %%
words_count_2 = Counter(token_2_gram)
def pro_2(word1,word2):
    if word1+word2 in token_2_gram:
        return words_count_2[word1+word2]/len(token_2_gram)
    else:
        return 1/len(token_2_gram)

# %%
pro_2('xiao','mi')
# Out:
# 1.2022852628988581e-05

# %%
Token_str = [str(t) for t in Tokens]
words_count_1 = Counter(Token_str)
def pro_1(word):
    if word in Token_str:
        return words_count_1[word]/len(Token_str)
    else:
        return 1/len(Token_str)

# %%
# woyaoshangqinghua 
@memo
def r(n):


    max_price, max_split = max(
        [(pro_1(string[:n]), 0)] + [(r(i) + r(n-i), i) for i in range(1, n)], key=lambda x: x[0]
    )

    solution[n] = (n - max_split, max_split)
    print(max_split)
    
    return max_price

# %%
string = 'guanguanjujiuzaihezhizhou' 
number = len(string)
print(number)
r(number)
# Out:
# 25
# 0
# 0
# 1
# 0
# 1
# 2
# 1
# 4
# 1
# 2
# 3
# 4
# 1
# 2
# 4
# 4
# 1
# 2
# 4
# 4
# 1
# 2
# 4
# 4
# 1
# 0.03185083784411458

# %%
solution
# Out:
# {1: (1, 0),
#  2: (2, 0),
#  3: (2, 1),
#  4: (4, 0),
#  5: (4, 1),
#  6: (4, 2),
#  7: (6, 1),
#  8: (4, 4),
#  9: (8, 1),
#  10: (8, 2),
#  11: (8, 3),
#  12: (8, 4),
#  13: (12, 1),
#  14: (12, 2),
#  15: (11, 4),
#  16: (12, 4),
#  17: (16, 1),
#  18: (16, 2),
#  19: (15, 4),
#  20: (16, 4),
#  21: (20, 1),
#  22: (20, 2),
#  23: (19, 4),
#  24: (20, 4),
#  25: (24, 1)}

# %%
# 感觉这里切完词之后
split = parse_solution(number)
print(split)
# Out:
# [4, 4, 4, 4, 4, 4, 1]

# %%
a = []
tmp = 0
sum = [0]
for i in range(len(split)):
    tmp += split[i]
    sum.append(tmp)
# print(sum)
for j in range(len(sum)-1):
    a.append(string[sum[j]:sum[j+1]])
print('纠正前拼音为：{}'.format(' '.join(a)))
print('纠正后拼音为：')
print(sequence_corect(' '.join(a)))
# Out:
# 纠正前拼音为：guan guan juji uzai hezh izho u
# 纠正后拼音为：
# guan guan ji zai he zhi u
